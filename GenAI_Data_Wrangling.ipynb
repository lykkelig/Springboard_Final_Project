# %% [markdown]
# ### GenAI_Data_Wrangling
# #### Data wrangling of notes so that male notes align with male patients and female notes align with female patients

# %%
import os
import pandas as pd

# %%
# Directory path for medical_records.csv
directory_path = 'Medical_Records_Dataset/medical_records.csv'

medical_records = pd.read_csv(directory_path)
medical_records.head()
# Out:
#    patient_id              name date_of_birth gender  \
# 0           1        Scott Webb    1967-04-28      F
# 1           2  Rachel Frederick    1977-04-04      M
# 2           3        Eric Kline    1926-05-18      F
# 3           4   James Rodriguez    1954-07-20      M
# 4           5       David Scott    2015-12-07      M
#
#                   medical_conditions                  medications  \
# 0               Mrs, story, security        example, parent, city
# 1  performance, participant, surface             be, develop, guy
# 2        quite, about, international  station, situation, popular
# 3               him, sea, television           about, item, often
# 4             make, moment, physical     deep, letter, difference
#
#                         allergies last_appointment_date
# 0              each, product, two            2022-07-26
# 1  north, hospital, international            2023-02-14
# 2                 tree, other, at            2021-04-24
# 3         discuss, play, somebody            2022-05-26
# 4            because, true, blood            2021-05-17

# %%
# Directory path for mtsamples.csv
directory_path = 'Medical_Transcriptions/mtsamples.csv'

mtsamples = pd.read_csv(directory_path)
mtsamples.head()
# Out:
#    Unnamed: 0                                        description  \
# 0           0   A 23-year-old white female presents with comp...
# 1           1           Consult for laparoscopic gastric bypass.
# 2           2           Consult for laparoscopic gastric bypass.
# 3           3                             2-D M-Mode. Doppler.
# 4           4                                 2-D Echocardiogram
#
#              medical_specialty                                sample_name  \
# 0         Allergy / Immunology                         Allergic Rhinitis
# 1                   Bariatrics   Laparoscopic Gastric Bypass Consult - 2
# 2                   Bariatrics   Laparoscopic Gastric Bypass Consult - 1
# 3   Cardiovascular / Pulmonary                    2-D Echocardiogram - 1
# 4   Cardiovascular / Pulmonary                    2-D Echocardiogram - 2
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
#
#                                             keywords
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...

# %%
# mtsamples = mtsamples.drop('Unnamed: 0', axis=1)
mtsamples = mtsamples.rename(columns={'Unnamed: 0': 'Patient_Num'})

# %%
print(mtsamples.columns)
# Out:
# Index(['Patient_Num', 'description', 'medical_specialty', 'sample_name',
#        'transcription', 'keywords'],
#       dtype='object')

# %%
# Define the set of words searching for that should only apply to Males and the words to exclude that whould only apply to Female
words_include = ['circumcision', 'male', 'man', 'mister','mr.', 'penis', 'penile', 'prostate', 'testes', 'testis', 'testical']
pattern_include = '|'.join(words_include) 
words_exclude = ['female','hysterectomy', 'infant', 'lady', 'miss', 'mrs.', 'madam', 'mz.','pregnant', 'pregnancy', 'vagina', 
                 'vaginal','woman']
pattern_exclude = '|'.join(words_exclude) 

# Initialize a mask with all False values
final_mask = pd.Series([False] * len(mtsamples))

# List of columns for word search 
columns_to_search = ['description', 'transcription', 'keywords']

# Generate a mask for each column and combine them
for column in columns_to_search:
    mask_include = mtsamples[column].str.contains(pattern_include, case=False, na=False)
    mask_exclude = ~mtsamples[column].str.contains(pattern_exclude, case=False, na=False)
    final_mask |= (mask_include & mask_exclude)  # Combine with OR to include matches in any column

# Apply the combined mask to filter the DataFrame
m_filtered_df = mtsamples[final_mask]

# print(m_filtered_df.head(50))

# %%
# Male notes
m_filtered_df.count()
# Out:
# Patient_Num          1921
# description          1921
# medical_specialty    1921
# sample_name          1921
# transcription        1916
# keywords             1520
# dtype: int64

# %%
# Define the set of words searching for that should only apply to Females and the words to exclude that whould only apply to Males
words_exclude = ['circumcision', 'gentleman', 'infant','male', 'man', 'mister','mr.', 'penis', 'penile', 'prostate', 'testes', 'testis', 'testical','well-child']
pattern_exclude = '|'.join(words_exclude) 
words_include = ['endometrium', 'fimbriae', 'fornix', 'fundus', 'infundibulum', 'myometrium', 'perimetrium','abortion', 'breast','cervical', 'cervix', 'colposcopy', 'female','gynecology','gynecologist','hyperplasia', 'hysteroscopy', 'hysterectomy','lady', 'labia', 'lactate', 'lactation', 'leep', 'mammoplasty', 'mammogram', 'mammography', 'mastectomy', 'miss', 'mrs.', 'madam', 'menses', 'menstrual', 'menopause','miscarriage', 'myomectomy', 'mz.','ovary', 'ovarian' ,'pap smear','period', 'placenta','postmenopausal', 'pregnant', 'pregnancy', 'uterus', 'uterine','vagina', 'vaginal','vulva','woman', 'womb']
pattern_include = '|'.join(words_include) 

# Initialize a mask with all False values
final_mask = pd.Series([False] * len(mtsamples))

# List of columns to search 
columns_to_search = ['description', 'transcription', 'keywords']

# Generate a mask for each column and combine them
for column in columns_to_search:
    mask_include = mtsamples[column].str.contains(pattern_include, case=False, na=False)
    mask_exclude = ~mtsamples[column].str.contains(pattern_exclude, case=False, na=False)
    final_mask |= (mask_include & mask_exclude)  # Combine with OR to include matches in any column

# Apply the combined mask to filter the DataFrame
f_filtered_df = mtsamples[final_mask]

# %%
# Female notes
f_filtered_df.count()
# Out:
# Patient_Num          955
# description          955
# medical_specialty    955
# sample_name          955
# transcription        945
# keywords             798
# dtype: int64

# %%
print(f_filtered_df.head(50))
# Out:
#      Patient_Num                                        description  \
# 4              4                                 2-D Echocardiogram
# 6              6   Liposuction of the supraumbilical abdomen, re...
# 30            30   The patient noted for improving retention of ...
# 45            45   SPARC suburethral sling due to stress urinary...
# 107          107   Left communicating hydrocele.  Left inguinal ...
# 110          110   Pelvic tumor, cystocele, rectocele, and uteri...
# 113          113   Left hydrocelectomy.   This is a 67-year-old ...
# 122          122   Foul-smelling urine and stomach pain after me...
# 126          126                                     Epididymectomy
# 172          172   Bladder instillation for chronic interstitial...
# 182          182   Visually significant posterior capsule opacit...
# 204          204   Laparoscopic-assisted vaginal hysterectomy.  ...
# 205          205   Vaginal Hysterectomy.  A weighted speculum wa...
# 206          206   Vacuum-assisted vaginal delivery of a third-d...
# 208          208    Upper endoscopy with removal of food impaction.
# 209          209   Exam under anesthesia with uterine suction cu...
# 213          213   A 21-year-old female was having severe crampi...
# 227          227   True cut needle biopsy of the breast.  This 6...
# 230          230                    Laparoscopic tubal fulguration.
# 232          232   Insertion of a triple-lumen central line thro...
# 260          260   Total abdominal hysterectomy (TAH) with a ute...
# 261          261   Aortic stenosis.   Insertion of a Toronto ste...
# 262          262   Total abdominal hysterectomy..  Severe menome...
# 263          263   Total Abdominal Hysterectomy (TAH).  An incis...
# 264          264   Total abdominal hysterectomy.  Enlarged fibro...
# 266          266   Tonsillectomy and adenoidectomy and Left supe...
# 302          302   Total abdominal hysterectomy (TAH) with a rig...
# 303          303   Total abdominal hysterectomy (TAH) with bilat...
# 304          304   Total abdominal hysterectomy (TAH), left salp...
# 307          307   Total abdominal hysterectomy (TAH) and left s...
# 309          309   Total abdominal hysterectomy and bilateral sa...
# 310          310   Missed abortion.  Suction, dilation, and cure...
# 325          325   Spontaneous vaginal delivery.  Male infant, c...
# 326          326   Spontaneous vaginal delivery.   Term pregnanc...
# 336          336   SPARC suburethral sling due to stress urinary...
# 381          381   Acute lymphocytic leukemia in remission, remo...
# 389          389   Closure of rectovaginal fistula, transperinea...
# 393          393   Modified radical mastectomy.  An elliptical i...
# 394          394   Invasive carcinoma of left breast. Left modif...
# 396          396   Radical vulvectomy (complete), bilateral ingu...
# 399          399   Exploratory laparotomy, radical hysterectomy,...
# 409          409   Right pterional craniotomy with obliteration ...
# 412          412   Right subclavian Port-a-Cath insertion in a p...
# 423          423    Chest tube talc pleurodesis of the right chest.
# 429          429   Left hemothorax, rule out empyema.  Insertion...
# 452          452   Perlane injection for the nasolabial fold.  R...
# 454          454   A 14-year-old young lady is in the renal fail...
# 511          511   Nipple areolar reconstruction utilizing a ful...
# 519          519   Needle-localized excisional biopsy, left brea...
# 521          521   Needle-localized excisional biopsy of the lef...
#
#                medical_specialty  \
# 4     Cardiovascular / Pulmonary
# 6                     Bariatrics
# 30                       Urology
# 45                       Urology
# 107                      Urology
# 110                      Urology
# 113                      Urology
# 122                      Urology
# 126                      Urology
# 172                      Urology
# 182                      Surgery
# 204                      Surgery
# 205                      Surgery
# 206                      Surgery
# 208                      Surgery
# 209                      Surgery
# 213                      Surgery
# 227                      Surgery
# 230                      Surgery
# 232                      Surgery
# 260                      Surgery
# 261                      Surgery
# 262                      Surgery
# 263                      Surgery
# 264                      Surgery
# 266                      Surgery
# 302                      Surgery
# 303                      Surgery
# 304                      Surgery
# 307                      Surgery
# 309                      Surgery
# 310                      Surgery
# 325                      Surgery
# 326                      Surgery
# 336                      Surgery
# 381                      Surgery
# 389                      Surgery
# 393                      Surgery
# 394                      Surgery
# 396                      Surgery
# 399                      Surgery
# 409                      Surgery
# 412                      Surgery
# 423                      Surgery
# 429                      Surgery
# 452                      Surgery
# 454                      Surgery
# 511                      Surgery
# 519                      Surgery
# 521                      Surgery
#
#                                            sample_name  \
# 4                              2-D Echocardiogram - 2
# 6                                         Liposuction
# 30                       Urinary Retention - Followup
# 45                          Sling (SPARC Suburethral)
# 107                Inguinal Hernia & Hydrocele Repair
# 110                Hysterectomy, BSO, & Appendectomy.
# 113                                   Hydrocelectomy.
# 122                               Foul-Smelling Urine
# 126                                    Epididymectomy
# 172                              Bladder Instillation
# 182                             YAG Laser Capsulotomy
# 204      Vaginal Hysterectomy - Laparoscopic-Assisted
# 205                              Vaginal Hysterectomy
# 206                Vaginal Delivery - Vacuum-Assisted
# 208                                  Upper Endoscopy
# 209                         Uterine Suction Curettage
# 213                                        Vacuum D&C
# 227                   True Cut Needle Biopsy - Breast
# 230                 Tubal Fulguration - Laparoscopic
# 232                        Ttriple-Lumen Central Line
# 260                  Total Abdominal Hysterectomy - 3
# 261                   Toronto Porcine Valve Insertion
# 262                  Total Abdominal Hysterectomy - 1
# 263                      Total Abdominal Hysterectomy
# 264                  Total Abdominal Hysterectomy - 2
# 266                 Tonsillectomy & Adenoidectomy - 4
# 302                   TAH & Salpingo-oophorectomy - 1
# 303                        TAH & Salpingooophorectomy
# 304   TAH & Salpingo-oophorectomy & Lysis of Adhesi...
# 307                       TAH & Salpingo-oophorectomy
# 309                                         TAH & BSO
# 310                    Suction, Dilation, & Curettage
# 325                  Spontaneous Vaginal Delivery - 1
# 326                      Spontaneous Vaginal Delivery
# 336                         Sling (SPARC Suburethral)
# 381                            Removal of Venous Port
# 389                      Rectovaginal Fistula Closure
# 393                            Radical Mastectomy - 1
# 394                                Radical Mastectomy
# 396                                Radical Vulvectomy
# 399                              Radical Hysterectomy
# 409                              Pterional Craniotomy
# 412                         Port-A-Cath Insertion - 1
# 423                                       Pleurodesis
# 429                        Pigtail Catheter Insertion
# 452                     Perlane & Restylane Injection
# 454            Peritoneal Dialysis Catheter Insertion
# 511                             Nipple Reconstruction
# 519       Needle-Localized Excisional Biopsy - Breast
# 521   Needle-Localized Excisional Biopsy - Breast - 1
#
#                                          transcription  \
# 4    1.  The left ventricular cavity size and wall ...
# 6    PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 30   HISTORY OF PRESENT ILLNESS: , The patient pres...
# 45   PREOPERATIVE DX: , Stress urinary incontinence...
# 107  PREOPERATIVE DIAGNOSIS:  ,Left communicating h...
# 110  1.  Pelvic tumor.,2.  Cystocele.,3.  Rectocele...
# 113  PREOPERATIVE DIAGNOSIS: , Left hydrocele.,OPER...
# 122  CHIEF COMPLAINT:,  Foul-smelling urine and sto...
# 126  EPIDIDYMECTOMY,OPERATIVE NOTE:  ,The patient w...
# 172  CHIEF COMPLAINT:,  The patient comes for bladd...
# 182  PREOPERATIVE DIAGNOSIS:,  Visually significant...
# 204  PREOPERATIVE DIAGNOSES,1.  Abnormal uterine bl...
# 205                                                NaN
# 206  PREOPERATIVE DIAGNOSES,1.  A 40 weeks 6 days i...
# 208  PROCEDURE:,  Upper endoscopy with removal of f...
# 209  PREOPERATIVE DIAGNOSIS: , A 10-1/2 week pregna...
# 213  PREOPERATIVE DIAGNOSIS: , Blighted ovum, sever...
# 227  PREOPERATIVE DIAGNOSIS:,  Carcinoma of the lef...
# 230  A 1 cm infraumbilical skin incision was made. ...
# 232  PREOPERATIVE DIAGNOSES,1.  Bowel obstruction.,...
# 260  PREOPERATIVE DIAGNOSES:,1.  Enlarged fibroid u...
# 261  PREOPERATIVE DIAGNOSIS:,  Aortic stenosis.,POS...
# 262  PREOPERATIVE DIAGNOSES:,1.  Severe menometrorr...
# 263                                                NaN
# 264  PREOPERATIVE DIAGNOSES:,1.  Enlarged fibroid u...
# 266  PREOPERATIVE DIAGNOSES,1.  Recurrent tonsillit...
# 302  PREOPERATIVE DIAGNOSIS:  ,Persistent abnormal ...
# 303  PREOPERATIVE DIAGNOSES:,1.  Cervical intraepit...
# 304  PREOPERATIVE DIAGNOSES:,1.  Chronic pelvic pai...
# 307  PREOPERATIVE DIAGNOSES:,1.  Hypermenorrhea.,2....
# 309  PREOPERATIVE DIAGNOSES:,1.  Chronic pelvic pai...
# 310  PREOPERATIVE DIAGNOSIS: , Missed abortion.,POS...
# 325  PREOPERATIVE DIAGNOSES,1.  Intrauterine pregna...
# 326  PREOPERATIVE DIAGNOSIS: , Term pregnancy at 40...
# 336  PREOPERATIVE DX: , Stress urinary incontinence...
# 381  PREOPERATIVE DIAGNOSIS: , Acute lymphocytic le...
# 389  PREOPERATIVE DIAGNOSIS (ES):, Rectovaginal fis...
# 393  PROCEDURE PERFORMED: , Modified radical mastec...
# 394  PREOPERATIVE DIAGNOSIS:,  Invasive carcinoma o...
# 396  PREOPERATIVE DIAGNOSIS: , Clinical stage III s...
# 399  PREOPERATIVE DIAGNOSIS:,  Cervical adenocarcin...
# 409  PREOPERATIVE DIAGNOSIS:  ,Status post spontane...
# 412  PREOPERATIVE DIAGNOSES: ,1.  Bilateral breast ...
# 423  PREOPERATIVE DIAGNOSIS:,  Large recurrent righ...
# 429  PREOPERATIVE DIAGNOSIS:  ,Left hemothorax, rul...
# 452  PREOPERATIVE DIAGNOSES:  ,1.  Nasolabial mesio...
# 454  PREOPERATIVE DIAGNOSIS: , Renal failure.,POSTO...
# 511  PREOPERATIVE DIAGNOSES,1.  Surgical absence of...
# 519  PREOPERATIVE DIAGNOSIS:,  Suspicious microcalc...
# 521  PREOPERATIVE DIAGNOSIS: ,Left breast mass with...
#
#                                               keywords
# 4    cardiovascular / pulmonary, 2-d, doppler, echo...
# 6    bariatrics, breast reconstruction, excess, lma...
# 30   urology, urinary retention, dysuria, gross hem...
# 45   urology, stress urinary incontinence, foley ca...
# 107  urology, hydrocele, hydrocele repair, hernia, ...
# 110  urology, marshall-marchetti-krantz cystourethr...
# 113  urology, hydrocele, erectile dysfunction, sper...
# 122                                                NaN
# 126  urology, scrotal incision, 0.25% marcaine, bov...
# 172  urology, urethra, dmso, bladder, chronic inter...
# 182  surgery, capsule opacity, yag, ophthalmic, yag...
# 204  surgery, abnormal uterine bleeding, laparoscop...
# 205  surgery, omentum, massachusetts, vaginal hyste...
# 206  surgery, intrauterine pregnancy, non-reassurin...
# 208  surgery, dysphagia, removal of food impaction,...
# 209  surgery, spontaneous, incomplete abortion, ute...
# 213  surgery, pitocin, single tooth tenaculum, vagi...
# 227  surgery, carcinoma, true cut needle biopsy, ni...
# 230  surgery, tubal fulguration, cohen cannula, lap...
# 232  surgery, central line, triple lumen central li...
# 260                                                NaN
# 261  surgery, cardioplegia, toronto stentless porci...
# 262  surgery, menometrorrhagia, fibroid, uterus, to...
# 263  surgery, fundus, double-toothed tenaculum, mus...
# 264  surgery, pelvic pain, pelvic endometriosis, as...
# 266  surgery, tonsillitis, cryptic hypertrophic ton...
# 302  surgery, tah, salpingo-oophorectomy, total abd...
# 303  surgery, cervical intraepithelial neoplasia, v...
# 304  surgery, chronic pelvic pain, endometriosis, i...
# 307
# 309  surgery, tah, bso, total abdominal hysterectom...
# 310  surgery, missed abortion, intrauterine pregnan...
# 325  surgery, thick meconium, cephalic presentation...
# 326  surgery, roa position, arom, labor and deliver...
# 336  surgery, stress urinary incontinence, foley ca...
# 381  surgery, removal of venous port, acute lymphoc...
# 389  surgery, transperineal approach, fistula tract...
# 393  surgery, latissimus dorsi muscle, pectoralis m...
# 394  surgery, invasive carcinoma, chest wall, neck,...
# 396  surgery, squamous cell carcinoma, vulvectomy, ...
# 399  surgery, cervical adenocarcinoma, radical hyst...
# 409  surgery, hemorrhage, arteriovenous malformatio...
# 412  surgery, carcinoma, bilateral breast carcinoma...
# 423  surgery, chest tube talc pleurodesis, lateral ...
# 429  surgery, chest, pleural space, pigtail cathete...
# 452  surgery, lasercaine, nasolabial mesiolabial fo...
# 454  surgery, pd catheter, catheter, omentum, perit...
# 511  surgery, nipple areola, breast asymmetry, gene...
# 519  surgery, suspicious microcalcifications, needl...
# 521  surgery, needle localized excisional biopsy, e...

# %%
# Filter 'medical_records' to include only males
male_records = medical_records[medical_records['gender'] == 'M']

# Shuffle the male DataFrame to get a random sample
male_records_shuffled = male_records.sample(frac=1).reset_index(drop=True)

# Reset index on m_filtered_df to ensure sequential indices
m_filtered_df_reset = m_filtered_df.reset_index(drop=True)

# %%
male_records_shuffled.count()
# Out:
# patient_id               50208
# name                     50208
# date_of_birth            50208
# gender                   50208
# medical_conditions       50208
# medications              50208
# allergies                50208
# last_appointment_date    50208
# dtype: int64

# %%
m_filtered_df_reset.count()
# Out:
# Patient_Num          1921
# description          1921
# medical_specialty    1921
# sample_name          1921
# transcription        1916
# keywords             1520
# dtype: int64

# %%
# Ensure male_records_shuffled has the same number of rows as m_filtered_df_reset
male_records_shuffled = male_records_shuffled.iloc[:len(m_filtered_df_reset)]

# %%
male_records_shuffled.count()
# Out:
# patient_id               1921
# name                     1921
# date_of_birth            1921
# gender                   1921
# medical_conditions       1921
# medications              1921
# allergies                1921
# last_appointment_date    1921
# dtype: int64

# %%
# Merge the rows based on their indices
# Since we're aligning by index, join on the indices directly
m_new_df = m_filtered_df_reset.join(male_records_shuffled, lsuffix='_m_filtered', rsuffix='_male_records')

# %%
m_new_df.head(10)
# Out:
#    Patient_Num                                        description  \
# 0            2           Consult for laparoscopic gastric bypass.
# 1           10   Morbid obesity.  Laparoscopic Roux-en-Y gastr...
# 2           15   Preoperative visit for weight management with...
# 3           16   Neck exploration; tracheostomy; urgent flexib...
# 4           18   Fertile male with completed family.  Elective...
# 5           20   Whole body radionuclide bone scan due to pros...
# 6           21   Patient discharged after laparoscopic Roux-en...
# 7           22                                   Normal vasectomy
# 8           23   Voluntary sterility.  Bilateral vasectomy.  T...
# 9           26   Hispanic male patient was admitted because of...
#
#              medical_specialty                                    sample_name  \
# 0                   Bariatrics       Laparoscopic Gastric Bypass Consult - 1
# 1                   Bariatrics               Laparoscopic Gastric Bypass - 1
# 2                   Bariatrics   Laparoscopic Gastric Banding - Preop Visit
# 3   Cardiovascular / Pulmonary                                  Tracheostomy
# 4                      Urology                                 Vasectomy - 4
# 5                      Urology             Whole Body Radionuclide Bone Scan
# 6                   Bariatrics                        Gastric Bypass Summary
# 7                      Urology                                 Vasectomy - 1
# 8                      Urology                                     Vasectomy
# 9                      Urology                     Urology Discharge Summary
#
#                                        transcription  \
# 0  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 1  PREOPERATIVE DIAGNOSIS: , Morbid obesity. ,POS...
# 2  HISTORY OF PRESENT ILLNESS: ,I have seen ABC t...
# 3  PREOPERATIVE DIAGNOSES,Airway obstruction seco...
# 4  PROCEDURE: , Elective male sterilization via b...
# 5  INDICATION:,  Prostate Cancer.,TECHNIQUE:,  3....
# 6  FINAL DIAGNOSES,1.  Morbid obesity, status pos...
# 7  DESCRIPTION:,  The patient was placed in the s...
# 8  PREOPERATIVE DIAGNOSIS: , Voluntary sterility....
# 9  PROCEDURES:, Cystourethroscopy and transurethr...
#
#                                             keywords  patient_id  \
# 0  bariatrics, laparoscopic gastric bypass, heart...       70800
# 1  bariatrics, morbid obesity, roux-en-y, gastric...       40271
# 2  bariatrics, laparoscopic gastric banding, pulm...       97297
# 3  cardiovascular / pulmonary, airway, laryngolog...       67395
# 4  urology, sterilization, vas, fertile male, bil...       68982
# 5  urology, prostate cancer, technetium, whole bo...        2311
# 6  bariatrics, medifast, laparoscopic roux-en-y g...       12453
# 7  urology, vasectomy, allis clamp, catgut, hemoc...       40949
# 8  urology, hemiscrotum, bilateral vasectomy, vol...       17330
# 9  urology, tur, bun, cystourethroscopy, difficul...       15846
#
#                name date_of_birth gender         medical_conditions  \
# 0  Patrick Espinoza    1933-12-16      M           know, last, past
# 1   Yolanda Simpson    1950-01-02      M      property, key, window
# 2    Andrew Aguilar    1956-07-01      M          single, prove, to
# 3      Joseph Brown    1970-07-12      M   enough, audience, police
# 4    Jennifer Moore    1925-10-27      M        green, sport, seven
# 5      Peter Burton    1991-11-01      M            son, cold, four
# 6       James Kelly    1982-11-18      M      amount, wear, clearly
# 7        Mary Myers    1976-01-28      M       moment, word, factor
# 8    Elizabeth Dunn    1959-08-07      M  available, option, finish
# 9       Erik Powers    2016-09-29      M           part, good, that
#
#                     medications                   allergies  \
# 0              artist, test, we        lose, believe, music
# 1             cup, artist, tend  forget, organization, year
# 2             system, if, again           fall, local, care
# 3        result, through, claim         child, across, ball
# 4        full, voice, challenge  everything, floor, finally
# 5     nothing, structure, price  evidence, outside, receive
# 6        meeting, material, law         pretty, team, style
# 7     have, account, government    study, significant, meet
# 8  south, interesting, hospital         lawyer, trip, visit
# 9            hard, tough, floor           amount, fill, nor
#
#   last_appointment_date
# 0            2022-03-11
# 1            2022-05-17
# 2            2022-06-07
# 3            2021-08-27
# 4            2022-02-05
# 5            2022-05-02
# 6            2021-06-10
# 7            2022-11-15
# 8            2022-10-19
# 9            2021-10-05

# %%
# Filter 'medical_records' to include only Females
female_records = medical_records[medical_records['gender'] == 'F']

# Shuffle the Female DataFrame
female_records_shuffled = female_records.sample(frac=1).reset_index(drop=True)

# Reset index on f_filtered_df to ensure sequential indices
f_filtered_df_reset = f_filtered_df.reset_index(drop=True)

# %%
female_records_shuffled.count()
# Out:
# patient_id               49792
# name                     49792
# date_of_birth            49792
# gender                   49792
# medical_conditions       49792
# medications              49792
# allergies                49792
# last_appointment_date    49792
# dtype: int64

# %%
f_filtered_df_reset.count()
# Out:
# Patient_Num          955
# description          955
# medical_specialty    955
# sample_name          955
# transcription        945
# keywords             798
# dtype: int64

# %%
# Ensure female_records_shuffled has the same number of rows as f_filtered_df_reset
female_records_shuffled = female_records_shuffled.iloc[:len(f_filtered_df_reset)]

# %%
# Merge the rows based on their indices
# Since we're aligning by index, join on the indices directly
f_new_df = f_filtered_df_reset.join(female_records_shuffled, lsuffix='_f_filtered', rsuffix='_female_records')

# %%
f_new_df.columns
# Out:
# Index(['Patient_Num', 'description', 'medical_specialty', 'sample_name',
#        'transcription', 'keywords', 'patient_id', 'name', 'date_of_birth',
#        'gender', 'medical_conditions', 'medications', 'allergies',
#        'last_appointment_date'],
#       dtype='object')

# %%
m_new_df.columns
# Out:
# Index(['Patient_Num', 'description', 'medical_specialty', 'sample_name',
#        'transcription', 'keywords', 'patient_id', 'name', 'date_of_birth',
#        'gender', 'medical_conditions', 'medications', 'allergies',
#        'last_appointment_date'],
#       dtype='object')

# %%
# Combine the f_new_df and m_new_df DataFrames
combined_df = pd.concat([f_new_df, m_new_df], ignore_index=True)

# %%
combined_df.count()
# Out:
# Patient_Num              2876
# description              2876
# medical_specialty        2876
# sample_name              2876
# transcription            2861
# keywords                 2318
# patient_id               2876
# name                     2876
# date_of_birth            2876
# gender                   2876
# medical_conditions       2876
# medications              2876
# allergies                2876
# last_appointment_date    2876
# dtype: int64

# %%
# Write combined_df to an Excel file
combined_df.to_excel('combined_patient_records.xlsx', index=False)
